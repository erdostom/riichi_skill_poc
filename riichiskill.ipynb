# %%
import pandas as pd

# %%
df = pd.read_csv('trr.csv')

# %%
df
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Player 1 Unnamed: 5  \
# 0           Date       Town        Han      Table       ID     Result
# 1     2022-06-08       Łódź          1          1  PLPZ008     -10000
# 2     2022-06-08       Łódź          1          2  PLKA002       -500
# 3     2022-06-08       Łódź          1          3  GBXX007     -28800
# 4     2022-06-08       Łódź          1          4  PLXX008      31200
# ...          ...        ...        ...        ...      ...        ...
# 4702  2024-11-16  Stockholm          7         11  DEXX075       7100
# 4703  2024-11-16  Stockholm          7         12  SEXX013      28600
# 4704  2024-11-16  Stockholm          7         13  SEXX003     -37500
# 4705  2024-11-16  Stockholm          7         14  SEXX004      19900
# 4706  2024-11-16  Stockholm          7         15  SEXX024       9500
#
#      Player 2 Unnamed: 7 Player 3 Unnamed: 9 Player 4 Unnamed: 11
# 0          ID     Result       ID     Result       ID      Result
# 1     PLXX029       5100  PLLD004     -21200  PLRZ002       26100
# 2     PLXX014      30100  PLKA004      16100  PLGS004      -45700
# 3     PLXX019      -2500  PLXX022      44100  PLXX026      -30000
# 4     PLLD002      -9300  PLGS001     -38600  PLXX030       16700
# ...       ...        ...      ...        ...      ...         ...
# 4702  SEXX028      -3000  SEXX010     -22200  DEXX059       18100
# 4703  SEXX035     -31500  SEXX006      13400  SEXX009      -10500
# 4704  SEXX029      13200  SEWC002      36400  SEXX015      -12100
# 4705  SEXX014      -7700  SEXX023     -18900  SEXX038        6700
# 4706  SEXX033     -40700  SEXX011      48800  FIXX009      -17600
#
# [4707 rows x 12 columns]

# %%
from openskill.models import PlackettLuce

# %%
model = PlackettLuce()

# %%
print(model)
# Out:
# Plackett-Luce Model Parameters:
#
# mu: 25.0
# sigma: 8.333333333333334

# %%
players = {}

# %%
def find_or_create_player(name):
    if name not in players:
        players[name] = model.rating(name=name)        
    return players[name]

# %%
x = df.iterrows()

# %%
z = list(x)

# %%
def report_hanchan(p1,s1,p2,s2,p3,s3,p4,s4):
    scores = [s1,s2,s3,s4]
    match = [[p1],[p2],[p3],[p4]]
    [[p1],[p2],[p3],[p4]] = model.rate(match, scores=scores)
    players[p1.name] = p1
    players[p2.name] = p2
    players[p3.name] = p3
    players[p4.name] = p4
    return [p1,p2,p3,p4]

# %%
def report_row(row):
    p1 = find_or_create_player(row[4])
    p2 = find_or_create_player(row[6])
    p3 = find_or_create_player(row[8])
    p4 = find_or_create_player(row[10])
    s1 = int(row[5])
    s2 = int(row[7])
    s3 = int(row[9])
    s4 = int(row[11])
    return report_hanchan(p1,s1,p2,s2,p3,s3,p4,s4)

# %%
for row in z[1:]:
    report_row(row[1])
# Out:
# /tmp/ipykernel_41918/2749340963.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p1 = find_or_create_player(row[4])
# /tmp/ipykernel_41918/2749340963.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p2 = find_or_create_player(row[6])
# /tmp/ipykernel_41918/2749340963.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p3 = find_or_create_player(row[8])
# /tmp/ipykernel_41918/2749340963.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p4 = find_or_create_player(row[10])
# /tmp/ipykernel_41918/2749340963.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1 = int(row[5])
# /tmp/ipykernel_41918/2749340963.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s2 = int(row[7])
# /tmp/ipykernel_41918/2749340963.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s3 = int(row[9])
# /tmp/ipykernel_41918/2749340963.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s4 = int(row[11])

# %%
ranks = list(map(lambda player: [player, players[player].ordinal()], list(players.keys())))

# %%
list(reversed(sorted(ranks, key=lambda player: player[1])))
# Out:
# [['FRXX009', 26.387186695160675],
#  ['BEXX031', 23.831243258449945],
#  ['FRWC003', 23.614265485126317],
#  ['PLXX032', 23.387037964199656],
#  ['PLXX040', 23.177533081287432],
#  ['UAXX007', 22.950234620565737],
#  ['JPWC019', 22.92905115748139],
#  ['PLKR005', 22.877553847550274],
#  ['JPWC008', 22.296303664801005],
#  ['FRXX006', 22.103625133569867],
#  ['FRXX038', 21.937390310780405],
#  ['FIXX003', 21.90621816888679],
#  ['DECO001', 21.54349523355767],
#  ['CAWC001', 21.449507472243845],
#  ['BEWRL05', 21.27853604111982],
#  ['DEXX002', 20.87915815963113],
#  ['ATXX005', 20.876381929405735],
#  ['PLXX051', 20.657295896959255],
#  ['PLGS009', 20.58513116622626],
#  ['ATXX002', 20.504569851206796],
#  ['FRXX004', 20.389891349717548],
#  ['PLXX022', 20.26546474337786],
#  ['PLLD001', 20.176703542253932],
#  ['PLTR017', 20.149656444112267],
#  ['JPWC005', 19.940679792541562],
#  ['PLGS007', 19.81382216299294],
#  ['DEWRL01', 19.574121955820033],
#  ['BEXX014', 19.52851520516922],
#  ['BEWRL03', 19.50708089623517],
#  ['RUXX001', 19.37082573119],
#  ['PLKA001', 19.28115675278819],
#  ['REXX003', 19.246253599188037],
#  ['ATXX015', 19.20267346781767],
#  ['FRXX005', 19.09370587530965],
#  ['GBXX007', 18.833241595286573],
#  ['FRXX001', 18.724478352592502],
#  ['FRXX002', 18.703166966099662],
#  ['FRXX051', 18.623502571843694],
#  ['FRWRL01', 18.597514378905906],
#  ['PLMJ004', 18.548334756363733],
#  ['DEXX018', 18.543843100936563],
#  ['PLPZ006', 18.503130988812913],
#  ['ROWC001', 18.497722930171424],
#  ['PLKR004', 18.387702982900723],
#  ['PLTR001', 18.36546959205523],
#  ['PLGS001', 18.3582919562652],
#  ['JPTR001', 18.221943205818405],
#  ['FIWRL01', 18.211665144275752],
#  ['PT00003', 18.19147991582664],
#  ['PLGS003', 18.189822827787832],
#  ['PT00001', 18.186408634582186],
#  ['BEWRL02', 18.171776174239966],
#  ['DEXX054', 18.122876461448232],
#  ['CAMO001', 18.05401887218557],
#  ['HKWC003', 18.002955628810476],
#  ['FRWC005', 17.929266250103083],
#  ['PLKR003', 17.928862745411312],
#  ['NLXX003', 17.905618865141474],
#  ['JPWC027', 17.835249148475746],
#  ['FRXX003', 17.7494543950614],
#  ['DEXX040', 17.685175324107654],
#  ['USWC004', 17.67504527895546],
#  ['SEWRL01', 17.655175838187855],
#  ['BEXX005', 17.59576405432194],
#  ['ESXX001', 17.575233539051208],
#  ['UAXX006', 17.567856711501726],
#  ['PLKR010', 17.559016470251198],
#  ['BEWRL04', 17.481982009860612],
#  ['DEWRL02', 17.477903940956015],
#  ['UAXX005', 17.46289316857414],
#  ['UAXX002', 17.374594481331822],
#  ['DEXX012', 17.222049206175285],
#  ['DEXX013', 17.163159706713266],
#  ['PLXX014', 17.126525626522525],
#  ['GBXX030', 17.07494338380097],
#  ['GBXX004', 17.045536682524535],
#  ['CNXX001', 16.840745369462127],
#  ['DKWC003', 16.813736114769938],
#  ['DEXX028', 16.72837970282949],
#  ['DEXX019', 16.716594317967076],
#  ['GBXX040', 16.709597398090168],
#  ['FRXX011', 16.660284988511243],
#  ['DECO004', 16.629143254135744],
#  ['BEXX003', 16.434731345861888],
#  ['USXX002', 16.348524622522508],
#  ['GBXX005', 16.292005723173528],
#  ['NLXX015', 16.059248097608435],
#  ['BEXX018', 16.03854990498762],
#  ['NLXX017', 15.949427188838236],
#  ['FIXX001', 15.914631675551075],
#  ['SEXX027', 15.907828773122294],
#  ['BEXX010', 15.883221604277615],
#  ['FRXX058', 15.72428318874794],
#  ['PLTR014', 15.685756777434428],
#  ['PLTR018', 15.669198111079966],
#  ['UAXX053', 15.617293778385019],
#  ['DEXX053', 15.59763240607466],
#  ['DEXX010', 15.494829773844007],
#  ['FIXX005', 15.482850949644416],
#  ['JPXX003', 15.46639014588369],
#  ['ATXX003', 15.417739081621052],
#  ['DEXX022', 15.31029059010386],
#  ['PLGS002', 15.23266465408896],
#  ['JPWC020', 15.20731218707375],
#  ['PLXX110', 15.168496779631049],
#  ['PLXX044', 15.131186203537503],
#  ['PLKR012', 15.12716249803336],
#  ['CHXX004', 15.12044981808047],
#  ['FRXX039', 15.087800794832884],
#  ['ROXX003', 15.058903173186295],
#  ['NLXX006', 15.043722888479145],
#  ['PLXX016', 15.019011174473999],
#  ['SKXX005', 15.018464165959124],
#  ['DEXX015', 15.0040122193778],
#  ['PLGS004', 14.889637953626805],
#  ['DEXX037', 14.88078337433683],
#  ['BEXX058', 14.879089498126785],
#  ['GBWC003', 14.831469960726253],
#  ['BEXX027', 14.68812977356392],
#  ['FRXX065', 14.568369149803814],
#  ['GBXX012', 14.5369673797161],
#  ['PT00009', 14.48601139152153],
#  ['CHXX005', 14.441965327701375],
#  ['BEWRL01', 14.428343673667065],
#  ['IEXX006', 14.322272244999116],
#  ['DEXX047', 14.28932069247501],
#  ['DEXX041', 14.268105482722152],
#  ['PLXX003', 14.256093061790924],
#  ['FRXX007', 14.06995556305976],
#  ['ESXX002', 14.068587544556497],
#  ['BEXX011', 14.052052620178905],
#  ['ATXX011', 13.934730864570525],
#  ['PLGS008', 13.933301262610343],
#  ['DEXX003', 13.849496506411734],
#  ['ATXX004', 13.812024539380566],
#  ['BEXX023', 13.781382529196442],
#  ['FRXX021', 13.747565781190534],
#  ['IEXX009', 13.675637358111658],
#  ['FRXX052', 13.652589858217635],
#  ['ITWC002', 13.645674206440845],
#  ['GBXX013', 13.554467437157387],
#  ['BEXX001', 13.484206219593311],
#  ['SEXX001', 13.482975224162171],
#  ['FRXX014', 13.479567268387495],
#  ['BEXX020', 13.464829013622506],
#  ['UAXX059', 13.360591103759425],
#  ['JPWC013', 13.351580022856545],
#  ['PLPZ010', 13.347051034039463],
#  ['FRXX020', 13.324281717451171],
#  ['PT00008', 13.303019777224634],
#  ['GBXX033', 13.298118735891595],
#  ['ATXX001', 13.291111435037873],
#  ['ATXX012', 13.287109114186848],
#  ['FRXX057', 13.275370958403528],
#  ['PLXX012', 13.258820693702397],
#  ['PLMJ002', 13.241584091117197],
#  ['PLWA001', 13.219598599127107],
#  ['NLXX018', 13.209187152659553],
#  ['BEXX009', 13.20120379415231],
#  ['FRXX034', 13.176995549032007],
#  ['UAXX004', 13.162141545538233],
#  ['ATXX024', 13.088942673523487],
#  ['UAXX011', 13.072747875170492],
#  ['DKXX003', 13.055861827049858],
#  ['DEXX025', 13.019813716088317],
#  ['PLGS012', 12.972996873418026],
#  ['FRXX071', 12.936303628855324],
#  ['DEXX014', 12.90244128282885],
#  ['BEXX034', 12.847486693674007],
#  ['PLXX122', 12.78636636357243],
#  ['BEXX004', 12.782397978131609],
#  ['PLKR016', 12.718146632708812],
#  ['GBXX006', 12.654454612029717],
#  ['SEXX009', 12.552195525784306],
#  ['GBXX027', 12.446059542569579],
#  ['REXX002', 12.41125557432013],
#  ['ESXX009', 12.395947329961249],
#  ['HKWC001', 12.381166606482633],
#  ['UAXX010', 12.325070898418986],
#  ['UAXX050', 12.260526952365293],
#  ['GBXX025', 12.1750432576371],
#  ['BEXX049', 12.170056393295926],
#  ['DEXX001', 12.144937635421044],
#  ['PLXX124', 12.092056908238924],
#  ['PLXX004', 12.062956211250622],
#  ['BEXX015', 12.062894860969674],
#  ['PLMJ003', 12.04151855435046],
#  ['PLPZ008', 12.038416738272641],
#  ['BYXX009', 12.032834861298596],
#  ['ATXX007', 11.98861421733914],
#  ['FRXX053', 11.969187843222116],
#  ['UAXX046', 11.95599820971788],
#  ['JPWC031', 11.947698758721241],
#  ['FRXX048', 11.926840461339609],
#  ['GBXX037', 11.87894472401647],
#  ['PLKR009', 11.872581789202505],
#  ['BEXX042', 11.83834659999718],
#  ['FRXX015', 11.832459978787064],
#  ['PLGS006', 11.829922578675092],
#  ['DEXX046', 11.794357078507344],
#  ['ATXX013', 11.728949554438834],
#  ['PLKA004', 11.719511093112093],
#  ['PLTR011', 11.668859594018265],
#  ['CHXX001', 11.658118618559854],
#  ['CNXX002', 11.643296267416282],
#  ['PLKA101', 11.614949313096634],
#  ['GBXX010', 11.536481776251367],
#  ['PLPZ012', 11.527086161471754],
#  ['CZXX001', 11.485898505706665],
#  ['PLLD005', 11.384702289171804],
#  ['FRXX018', 11.373275026163592],
#  ['SEXX039', 11.372595289432784],
#  ['BEXX012', 11.370938121683746],
#  ['SEXX002', 11.355317109534095],
#  ['DEXX020', 11.338711927090365],
#  ['CHWC002', 11.336264530706625],
#  ['GBXX036', 11.272871712285212],
#  ['GBXX043', 11.206257251653621],
#  ['SEWC002', 11.205999376064067],
#  ['USWC008', 11.08816409326698],
#  ['SGXX001', 11.062499963412574],
#  ['NLXX002', 11.048775897772522],
#  ['UAXX056', 11.015702037394718],
#  ['BEXX002', 11.007614195633744],
#  ['BEXX008', 10.99405608056213],
#  ['SEXX037', 10.984323155669543],
#  ['PT00006', 10.974953531232583],
#  ['PLTR002', 10.932466625058694],
#  ['PLGS005', 10.924858501922957],
#  ['CAXX002', 10.873124147761622],
#  ['PLBI001', 10.872631074190753],
#  ['PLXX045', 10.871501090929279],
#  ['BEXX039', 10.86912774140951],
#  ['PLTR009', 10.80675659987046],
#  ['FIXX007', 10.800529060455716],
#  ['BEXX047', 10.778755662054952],
#  ['USWC005', 10.761020125981176],
#  ['PLXX136', 10.681645390253387],
#  ['JPXX006', 10.667223166588208],
#  ['USWC007', 10.66457895081976],
#  ['NLXX004', 10.62311258630313],
#  ['HKXX001', 10.60636370693982],
#  ['DEXX065', 10.578156787051821],
#  ['DEXX049', 10.569500587401158],
#  ['PT00010', 10.518092744196608],
#  ['PLXX102', 10.490916882926092],
#  ['UAXX018', 10.45534114928257],
#  ['DEXX016', 10.451398080357603],
#  ['JPWC001', 10.441060875378497],
#  ['SEXX036', 10.352416902693179],
#  ['BEXX019', 10.343874320788746],
#  ['DEWC002', 10.329908417518318],
#  ['XXXX001', 10.279750002580197],
#  ['PLXX029', 10.224226503507904],
#  ['ATXX009', 10.221981468300038],
#  ['DKXX002', 10.207711934865033],
#  ['BEXX035', 10.156858321261048],
#  ['PLPZ016', 10.124496392887657],
#  ['FRXX016', 10.106392895989156],
#  ['IEXX013', 10.084222263818269],
#  ['BYXX010', 10.013337706694738],
#  ['GBXX022', 10.002492343111744],
#  ['FRXX013', 9.97900217313358],
#  ['JPWC022', 9.95274494978753],
#  ['PLRZ001', 9.932228759629378],
#  ['FRXX054', 9.884898201719459],
#  ['FRXX072', 9.872753674269195],
#  ['UAXX051', 9.815597407000716],
#  ['PLPZ005', 9.810395274464302],
#  ['PLWA004', 9.806134962303906],
#  ['DEXX017', 9.790533141291064],
#  ['GBXX026', 9.781977443185305],
#  ['GBXX023', 9.77798146539233],
#  ['GBXX001', 9.776968460694551],
#  ['PLWA003', 9.73886323317072],
#  ['FRXX044', 9.72888285227862],
#  ['XXWRL01', 9.72691554308269],
#  ['CAXX001', 9.71938953592554],
#  ['FRXX049', 9.699321799138573],
#  ['DEXX008', 9.686558139535943],
#  ['HUWC001', 9.634600999566075],
#  ['CAWC002', 9.614650285776374],
#  ['USXX001', 9.589244135186473],
#  ['BEXX043', 9.548618731822984],
#  ['DEXX009', 9.544889341671258],
#  ['ESXX004', 9.526116978913901],
#  ['DEXX007', 9.512631087866989],
#  ['DECO006', 9.509297163580008],
#  ['RUWC001', 9.489819303653135],
#  ['USWC006', 9.458825423083727],
#  ['UAXX032', 9.438324581398021],
#  ['BEXX007', 9.436245280100792],
#  ['HUWRL01', 9.430507620154359],
#  ['FIWC001', 9.410184680481194],
#  ['FRPA001', 9.393911422349394],
#  ['ITXX002', 9.38112661094421],
#  ['NLXX014', 9.376801636278152],
#  ['REXX001', 9.368113468153137],
#  ['NLXX022', 9.36087597140585],
#  ['NLXX008', 9.359711315596723],
#  ['JPTR002', 9.346129362893308],
#  ['JPWC011', 9.337445716020387],
#  ['SEXX011', 9.33735275578676],
#  ['ATXX020', 9.3331820148723],
#  ['GBXX019', 9.293693418650431],
#  ['FRXX022', 9.282972227627159],
#  ['JPWC032', 9.248191041118762],
#  ['NLXX011', 9.2448265597144],
#  ['JPXX005', 9.224185546056205],
#  ['PLGS010', 9.138874655447427],
#  ['PLXX033', 9.064960028275905],
#  ['PLKR013', 9.032882285014722],
#  ['GBXX017', 9.018949671108256],
#  ['NLXX001', 9.012381433625922],
#  ['DEXX063', 8.991779490924252],
#  ['PLXX034', 8.942419698129338],
#  ['DECO003', 8.938278355665538],
#  ['NLXX023', 8.914064610163052],
#  ['CHXX007', 8.881631845750295],
#  ['ATVI001', 8.872623168999418],
#  ['FRXX017', 8.843934713481762],
#  ['SEXX032', 8.774521335592961],
#  ['JPWC007', 8.753601720870932],
#  ['JPWC004', 8.750467500618502],
#  ['XXXD003', 8.745328726695536],
#  ['PLXX119', 8.74450042820423],
#  ['PLKR002', 8.71653914062266],
#  ['UAXX008', 8.703310852133889],
#  ['DEXX075', 8.686211683880906],
#  ['JPXX002', 8.678231461585227],
#  ['NLXX020', 8.631446921431735],
#  ['GBXX056', 8.626803391562397],
#  ['NLWC003', 8.620924011832109],
#  ['ATXX021', 8.601360730028059],
#  ['GBWC004', 8.56872600967072],
#  ['CNXX003', 8.568412933051938],
#  ['PLXX129', 8.541576277591052],
#  ['SKXX003', 8.52536530443945],
#  ['SEXX003', 8.503373318295075],
#  ['PLKR014', 8.502716845544857],
#  ['BEXX057', 8.43471046573644],
#  ['DEXX023', 8.426723042757413],
#  ['SKXX002', 8.395466482296744],
#  ['ATXX010', 8.387479672620174],
#  ['PLBI003', 8.37348914426833],
#  ['SGXX002', 8.361116307367098],
#  ['PLPZ004', 8.326934934823388],
#  ['ATXX008', 8.301452822348802],
#  ['DEXX056', 8.295451185727252],
#  ['PLGS011', 8.262292501926304],
#  ['PLXX123', 8.252634703572582],
#  ['ARWC001', 8.247286839276178],
#  ['DKWC002', 8.240371760187628],
#  ['DECO005', 8.228372136880699],
#  ['GBXX047', 8.185639413148333],
#  ['SKXX001', 8.175517654020862],
#  ['NLXX016', 8.13998842420267],
#  ['UAXX064', 8.137488589720565],
#  ['SEXX010', 8.13443388022505],
#  ['SEXX016', 8.130671558088817],
#  ['IEXX001', 8.10396737763897],
#  ['UAXX062', 8.094634483179707],
#  ['FRXX076', 8.06318241314387],
#  ['GBXX053', 8.062800411673136],
#  ['PLXX005', 8.024474410578545],
#  ['DEXX036', 8.016344963159742],
#  ['BYXX003', 7.994609503817621],
#  ['PLXX120', 7.949677610086031],
#  ['PLTR015', 7.947208106520311],
#  ['ATXX026', 7.9219183556483905],
#  ['JPWC010', 7.919482198194132],
#  ['UAXX031', 7.893653800670162],
#  ['JPWC023', 7.8716996114678786],
#  ['DEXX057', 7.864116606014477],
#  ['ESXX003', 7.859953478575495],
#  ['SEXX019', 7.858360746026001],
#  ['BEXX024', 7.753991688680266],
#  ['USWC001', 7.752905209083988],
#  ['GBXX039', 7.676529030981545],
#  ['GBXX060', 7.629012893265923],
#  ['NLXX007', 7.625820337736156],
#  ['ESXX007', 7.625338235907488],
#  ['PLTR020', 7.624645337911684],
#  ['USXX003', 7.610695989355026],
#  ['PLXX019', 7.587717405130697],
#  ['GBXX029', 7.585869864014569],
#  ['UAXX054', 7.584198192076187],
#  ['PLTR028', 7.572644287193992],
#  ['PLTR010', 7.558381908564339],
#  ['PLTR022', 7.548555164422776],
#  ['ROXX004', 7.53739527962124],
#  ['GBWC001', 7.523117042392162],
#  ['PLTR033', 7.494262508064782],
#  ['PLGS014', 7.491779784239377],
#  ['BYXX024', 7.481735704515447],
#  ['FRXX040', 7.457450121397336],
#  ['GBXX052', 7.447062683448635],
#  ['FRXX070', 7.426327722002327],
#  ['PLLD003', 7.413192095524256],
#  ['DKWC004', 7.399075544854284],
#  ['PLXX121', 7.3988209345218365],
#  ['USWC002', 7.395577497928272],
#  ['BEXX033', 7.373193327766494],
#  ['PLXX056', 7.356558089050019],
#  ['NLWC004', 7.2828462172162105],
#  ['PLKR011', 7.27281812548274],
#  ['PLTR023', 7.272512833459437],
#  ['FRXX027', 7.252143504438003],
#  ['GBXX015', 7.230164700001875],
#  ['DKXX007', 7.158101192620972],
#  ['PLPZ011', 7.1450510193521595],
#  ['GBXX018', 7.106954508662291],
#  ['BEXX022', 7.105296886731221],
#  ['DEXX058', 7.062764655191572],
#  ['PLRZ002', 7.053840637439347],
#  ['DEXX044', 7.0496577154465285],
#  ['PLXX015', 7.0410054487885745],
#  ['PLXX135', 6.9959224570518685],
#  ['SEWC001', 6.965900561261755],
#  ['BEXX016', 6.9135055629043265],
#  ['GBXX020', 6.887921069095018],
#  ['SEXX028', 6.881321335176931],
#  ['NLXX021', 6.877735242189932],
#  ['DEXX055', 6.847039779894168],
#  ['GBXX009', 6.8094133393275165],
#  ['FRXX036', 6.797114234282635],
#  ['BEXX040', 6.706308807703989],
#  ['DEXX066', 6.694015240575716],
#  ['PLMJ001', 6.675506199561713],
#  ['BEXX013', 6.67119763546723],
#  ['NLXX012', 6.671102155705007],
#  ['FRXX019', 6.669895820686598],
#  ['BYXX017', 6.663265992889482],
#  ['PLKR018', 6.639766466251537],
#  ['DEXX024', 6.639481863878494],
#  ['JPWC012', 6.589328562086269],
#  ['BEXX006', 6.582507866671001],
#  ['IEXX004', 6.5770322418292295],
#  ['SEXX008', 6.567731062963379],
#  ['DEXX021', 6.563083650702822],
#  ['GBXX042', 6.539561797476274],
#  ['XXXD002', 6.529044319211643],
#  ['PLKR006', 6.474626936435822],
#  ['PLXX099', 6.466835974223237],
#  ['NLXX024', 6.45242897780566],
#  ['DECO002', 6.421020764747759],
#  ['GBXX011', 6.389002411418268],
#  ['FIXX012', 6.357100420257307],
#  ['JPWC017', 6.331251604486873],
#  ['BEXX017', 6.28783181685122],
#  ['JPWC025', 6.2833068668645815],
#  ['FRWC001', 6.264913805994965],
#  ['UAXX063', 6.253993899408172],
#  ['SEXX030', 6.240603786633134],
#  ['DEXX026', 6.219892090762897],
#  ['FRXX047', 6.154926812990173],
#  ['UAXX061', 6.133369066910838],
#  ['TWWC002', 6.132187352485968],
#  ['PLTR026', 6.120607812958735],
#  ['GBXX016', 6.111681476355908],
#  ['CHXX002', 6.089116435846957],
#  ['PLXX037', 6.076973388860388],
#  ['DEXX051', 6.075460953421825],
#  ['GBXX021', 6.034951211612354],
#  ['DEXX011', 6.014314557825763],
#  ['DEXX031', 6.01368550744068],
#  ['BEXX056', 5.980616905486492],
#  ['UAXX060', 5.9586313927999655],
#  ['CLWC003', 5.951774851353196],
#  ['FIWC003', 5.947844542745788],
#  ['JPWC030', 5.947327128862252],
#  ['NOWC002', 5.911773103856039],
#  ['FRXX012', 5.8893165111362755],
#  ['GBXX046', 5.886188834370429],
#  ['FRXX025', 5.877633208613293],
#  ['FRXX059', 5.872915010520753],
#  ['IEXX008', 5.853552811514671],
#  ['CHWC001', 5.832126081657886],
#  ['UAXX065', 5.819869058119622],
#  ['PLXX127', 5.8194927750577605],
#  ['PLXX126', 5.8107053985884],
#  ['SEWRL02', 5.739371796926619],
#  ['FRXX037', 5.687472621215452],
#  ['FIXX008', 5.684135477949251],
#  ['SEXX020', 5.683189140122199],
#  ['GBXX008', 5.651090448039767],
#  ['PLBI004', 5.64966677150457],
#  ['GBXX049', 5.637022808599784],
#  ['DEXX064', 5.634602249872486],
#  ['GBXX032', 5.6317794224549935],
#  ['UAXX009', 5.617787243908008],
#  ['UAXX003', 5.617602081366069],
#  ['REXX004', 5.616164291903704],
#  ['DKXX009', 5.562811640132889],
#  ['BEXX021', 5.537552803608342],
#  ['UAXX047', 5.467050626651481],
#  ['FRXX008', 5.4487721920167225],
#  ['SEXX034', 5.370689370547673],
#  ['BEXX052', 5.349007585226747],
#  ['ESXX005', 5.157905403330695],
#  ['ATXX018', 5.150720064966375],
#  ['SEXX021', 5.105639166989352],
#  ['NLXX010', 5.079911624658646],
#  ['GBWC002', 5.040102159995609],
#  ['GBXX058', 5.012408842031011],
#  ['FRWC004', 5.008118812508101],
#  ['DEXX043', 4.9915000256999065],
#  ['GBXX014', 4.985291857703881],
#  ['PLXX133', 4.971759686584694],
#  ['FRXX060', 4.95650569456113],
#  ['GBXX062', 4.937872431100452],
#  ['JPWC021', 4.935845730555808],
#  ['JPWC034', 4.887187705016764],
#  ['DKXX008', 4.862736121469627],
#  ['ITXX001', 4.828723307521749],
#  ['BRWC003', 4.827032410821552],
#  ['DKXX005', 4.809146319220755],
#  ['UAXX045', 4.786888778250589],
#  ['ATXX019', 4.749507569622807],
#  ['CLWC001', 4.722679797423947],
#  ['UAXX028', 4.714598350517139],
#  ['BEXX054', 4.702694794441488],
#  ['PLLD004', 4.699032950732548],
#  ['PLXX104', 4.687562087206835],
#  ['PLKA005', 4.679998521155785],
#  ['ROXX005', 4.66780768768955],
#  ['BEXX053', 4.661497989607589],
#  ['PLLD002', 4.56158179936687],
#  ['DEXX050', 4.457610399762849],
#  ['BEXX050', 4.457501066256732],
#  ['UAXX049', 4.424527502285269],
#  ['GBXX031', 4.408348471896556],
#  ['SEXX014', 4.403817446605853],
#  ['GBXX061', 4.334408819745363],
#  ['FRXX032', 4.311099723021744],
#  ['JPWC015', 4.298722856700159],
#  ['USWC009', 4.295241234405356],
#  ['AUWC002', 4.264203915712983],
#  ['GBWC005', 4.23852173048429],
#  ['ROXX002', 4.236727355226446],
#  ['ATXX016', 4.233248079490753],
#  ['PLXX130', 4.219173144944673],
#  ['FRXX063', 4.2059931052341],
#  ['FIXX004', 4.189167703348996],
#  ['BEXX025', 4.14339664560304],
#  ['DEXX059', 4.1091603882177665],
#  ['AUWC003', 4.107877602932202],
#  ['BEXX030', 4.031711051112282],
#  ['BEXX046', 4.029885979654338],
#  ['JPWC026', 4.0181663245456285],
#  ['SEXX035', 4.016501327445027],
#  ['PLXX023', 3.9915509662049224],
#  ['UAXX055', 3.9592253865509512],
#  ['FRXX075', 3.9244244202956686],
#  ['GBXX063', 3.9240414125182497],
#  ['PLXX095', 3.8969674658026143],
#  ['PLKA002', 3.8904637677854694],
#  ['BEXX045', 3.8798070667746565],
#  ['DEXX074', 3.8599697061289895],
#  ['PLKR017', 3.8158478686743997],
#  ['JPWC014', 3.7992082818973536],
#  ['FRXX066', 3.7787114161296422],
#  ['AUWC004', 3.766678955955335],
#  ['PLPZ003', 3.761789427222311],
#  ['PLAN001', 3.748348428485663],
#  ['PLWA006', 3.7296729142099956],
#  ['ESXX008', 3.7070870827102453],
#  ['CHXX003', 3.6614680278377634],
#  ['FRXX067', 3.6592089426875347],
#  ['SGWC003', 3.579097222503947],
#  ['XXXD001', 3.5704931691015176],
#  ['BEXX044', 3.5198224287786584],
#  ['CNXX004', 3.5100969164220786],
#  ['FRXX068', 3.5089015799044354],
#  ['BEXX051', 3.4684037287044234],
#  ['JPWC033', 3.4643552567377114],
#  ['PLXX128', 3.454335387764104],
#  ['IEXX003', 3.4183583429337148],
#  ['PLXX125', 3.418173219385139],
#  ['USWC003', 3.3613897925501206],
#  ['GBXX034', 3.319516318668928],
#  ['FRXX042', 3.2944744795733953],
#  ['ARWC002', 3.2592837238254155],
#  ['FRXX035', 3.2255450910405017],
#  ['BRWC001', 3.1974482033455693],
#  ['INWC001', 3.1573400419192623],
#  ['HKXX003', 3.0777840474376568],
#  ['PLXX006', 3.074671294019197],
#  ['USWC010', 3.066453017691721],
#  ['JPWC006', 3.0659664267292754],
#  ['PLXX009', 3.060572495174533],
#  ['JPWC024', 3.0557317746886348],
#  ['PLXX026', 3.047064284971672],
#  ['PLXCPR4', 3.0195811747760075],
#  ['DEXX070', 2.99185646077769],
#  ['PLTR031', 2.9793727900048985],
#  ['UAXX029', 2.9331543666390267],
#  ['PLXX108', 2.859966688456577],
#  ['PLTR029', 2.8454251940465305],
#  ['DEXX045', 2.843865023497056],
#  ['DEXX061', 2.8372150908328955],
#  ['DEXX042', 2.7971055722057336],
#  ['IRWC001', 2.794691735181754],
#  ['UAXX048', 2.7901553554152727],
#  ['BEXX038', 2.7824592008957048],
#  ['FRXX033', 2.7603879881423836],
#  ['JPWC009', 2.7298233203956173],
#  ['USWC012', 2.6860636921919294],
#  ['ATXX023', 2.6643334947590525],
#  ['DEWC001', 2.6326079532395816],
#  ['FIXX002', 2.63202886909162],
#  ['GBXX045', 2.629011174696352],
#  ['CZXX004', 2.6164797869436747],
#  ['JPWC035', 2.534341719046175],
#  ['BRWC002', 2.528383827320397],
#  ['SEXX023', 2.4687557322725375],
#  ['GBXX054', 2.432117726895271],
#  ['FRXX030', 2.3565949138536304],
#  ['DEXX029', 2.344978769928499],
#  ['PLXX018', 2.3446511547520217],
#  ['SEXX007', 2.3267627741191674],
#  ['ATXX017', 2.3224961432059246],
#  ['CZXX002', 2.3053545044082],
#  ['FRXX074', 2.2727273367612746],
#  ['NLXX019', 2.2714203033606957],
#  ['FRXX023', 2.1738126756145064],
#  ['USXX004', 2.1518234425530416],
#  ['GBXX044', 2.0933658882549047],
#  ['FIWC002', 2.0829435347334595],
#  ['PLKR001', 2.0812550892042516],
#  ['PT00007', 2.0788396360948234],
#  ['JPWC029', 2.055261532497969],
#  ['FRXX024', 2.009889075606381],
#  ['PLPZ014', 1.8958790482891246],
#  ['USWC013', 1.8124731882680543],
#  ['SEXX017', 1.8062682448837073],
#  ['FRWC002', 1.7276838626236497],
#  ['DEFR001', 1.7168606278060778],
#  ['UAXX001', 1.6848924530854674],
#  ['IEXX011', 1.6532129962302697],
#  ['PLXX010', 1.6455487645288756],
#  ['DEXX034', 1.636800473229183],
#  ['NLXX005', 1.5818410675070105],
#  ['PLTR012', 1.5636263599475733],
#  ['TWWC001', 1.5198265060278544],
#  ['IEXX002', 1.488197360659953],
#  ['PLTR008', 1.479908981542497],
#  ['FRXX043', 1.44919378926879],
#  ['PLXCPR3', 1.4275688937511113],
#  ['PLTR027', 1.3892770643792147],
#  ['SEXX015', 1.347654887805458],
#  ['HKXX002', 1.3282829678678887],
#  ['PLTR004', 1.3181170093410426],
#  ['ATXX014', 1.3078554780342593],
#  ['UAXX057', 1.2884044747839134],
#  ['PLGS015', 1.2545903560307536],
#  ['PLXX097', 1.2526578808319186],
#  ['DEXX032', 1.2054282236657201],
#  ['USWC011', 1.1934608309836463],
#  ['PLKR015', 1.1817411253921755],
#  ['NLWC002', 1.172251726577155],
#  ['GBXX038', 1.1697675723082916],
#  ['GBXX051', 1.1358885107908527],
#  ['SEXX038', 1.1089021943107298],
#  ['FRXX055', 1.0965466288877046],
#  ['HKWC002', 1.0582740485245559],
#  ['PLXX047', 1.038581331281545],
#  ['PLXX132', 1.0083904853489045],
#  ['JPXX001', 0.9931348413355359],
#  ['PLXX041', 0.970383734072179],
#  ['NLXX013', 0.9592058470826892],
#  ['SEXX018', 0.9230389212751682],
#  ['SGWC001', 0.9079761873750734],
#  ['ESXX006', 0.8950486719554256],
#  ['BEXX041', 0.8712541380185179],
#  ['NOWC001', 0.8711452524473735],
#  ['NLWC005', 0.8438475405406223],
#  ['SEXX013', 0.7180345825139334],
#  ['PLXX008', 0.7174314939639963],
#  ['CZXX006', 0.6780471883568921],
#  ['PLXX030', 0.5892699381770008],
#  ['JPWC016', 0.5769393214379974],
#  ['NLXX009', 0.575182056106506],
#  ['FRXX073', 0.5576034900869224],
#  ['SEXX004', 0.5214229257724163],
#  ['DECO007', 0.5122815767367435],
#  ['SEXX024', 0.493565428896229],
#  ['PLTR016', 0.4902061786203262],
#  ['SEXX026', 0.488064939261978],
#  ['DKXX006', 0.46049188665940477],
#  ['AZXX001', 0.443287184239999],
#  ['PLTR003', 0.3941813892014707],
#  ['FRXX029', 0.38173161272891676],
#  ['GBXX059', 0.3379196589526039],
#  ['SEXX005', 0.3267663034350008],
#  ['JPWC018', 0.26402944716621946],
#  ['ITWC001', 0.25512132509511076],
#  ['FRXX064', 0.24250416820430942],
#  ['SEXX006', 0.23541891867760256],
#  ['INWC002', 0.20362736776221269],
#  ['UAXX052', 0.18697276388404305],
#  ['GBXX048', 0.157746937073437],
#  ['DKWC001', 0.15622830690194078],
#  ['DEXX027', 0.08714167304829701],
#  ['BEXX036', 0.08280856265055547],
#  ['DEXX060', 0.08243445103588343],
#  ['PLGS013', 0.06337897401406778],
#  ['PLTR006', 0.058400079710203556],
#  ['DEXX068', 0.020316147696380682],
#  ['UAXX044', -0.012664840315871118],
#  ['DKXX010', -0.02700448484376139],
#  ['DKXX004', -0.07426004478395143],
#  ['GBXX057', -0.1346218984780876],
#  ['ROXX001', -0.1401335996933426],
#  ['DEXX038', -0.15112094947658683],
#  ['FIXX006', -0.15195975942518913],
#  ['PT00012', -0.1867344293299915],
#  ['PLXX134', -0.19329610225123162],
#  ['JPXX004', -0.2019649715860794],
#  ['JPWC002', -0.22286091385609907],
#  ['PLTR025', -0.2493616460659389],
#  ['UAXX058', -0.26736761050874946],
#  ['FRWC006', -0.27241568452626197],
#  ['GBXX055', -0.3117462790405163],
#  ['DEXX030', -0.34883300242151805],
#  ['DEXX033', -0.4069461429274597],
#  ['CZXX003', -0.4467477257000212],
#  ['IEXX010', -0.44995415706691233],
#  ['PLXCPR1', -0.45350613369381776],
#  ['UAXX012', -0.5353741181842437],
#  ['PLXX100', -0.5424978621863161],
#  ['FIXX010', -0.5702870171657501],
#  ['PLXX035', -0.6556263677354046],
#  ['PLKR007', -0.761679821417566],
#  ['ATVI002', -0.783386457340363],
#  ['PLXCPR2', -0.8218213294630736],
#  ['SILJ001', -0.8749250979726888],
#  ['BEXX029', -0.8860114924995237],
#  ['DEXX067', -0.8961575173542187],
#  ['PT00005', -1.0016739800282046],
#  ['FRXX056', -1.0115386237859205],
#  ['DEXX073', -1.0172933780625968],
#  ['VNXX001', -1.0289025013353026],
#  ['PLXX113', -1.1112333907009244],
#  ['DEXX072', -1.2127194696908958],
#  ['PT00002', -1.242188350622495],
#  ['JPWC003', -1.246469045083856],
#  ['PLTR019', -1.3154222129802147],
#  ['PLXX001', -1.324277514342164],
#  ['PLXX049', -1.3871527194564024],
#  ['SEXX012', -1.5144807604732549],
#  ['FRXX028', -1.5484569268537811],
#  ['BEXX028', -1.5554892008316052],
#  ['RUWC002', -1.5606804797350904],
#  ['SEXX029', -1.561496390716492],
#  ['PLKA003', -1.7099681905811472],
#  ['PLPZ015', -1.722841462958927],
#  ['SKXX004', -1.7339398281535345],
#  ['SEXX031', -1.7880180089631814],
#  ['GBXX041', -1.8374969943802313],
#  ['IEXX014', -1.8541527497418109],
#  ['FRXX069', -1.8829925826597655],
#  ['URWC001', -2.0354826344123786],
#  ['ATXX022', -2.1212246546692377],
#  ['PLTR005', -2.282765739517158],
#  ['FRXX045', -2.4295523190966897],
#  ['PT00004', -2.503252101018724],
#  ['AUWC001', -2.5490210404098264],
#  ['DEXX039', -2.691007247724322],
#  ['PLTR024', -2.748920177689815],
#  ['FRXX062', -2.7615386952099996],
#  ['PLXX098', -2.7776348425381663],
#  ['PLXX112', -2.7993130186234154],
#  ['PLTR032', -2.8545675652194937],
#  ['FIXX009', -2.9420393362474933],
#  ['DEXX069', -2.9801130355865375],
#  ['GBXX050', -3.0348533585609268],
#  ['BEXX026', -3.0631724243227385],
#  ['FRXX031', -3.1627217336780156],
#  ['HKXX004', -3.3411423179004416],
#  ['ATXX025', -3.3652737177265593],
#  ['DKXX001', -3.4194424123866014],
#  ['ROXX006', -3.435326873305982],
#  ['PLXX137', -3.466536143145298],
#  ['IEXX007', -3.516343142381256],
#  ['IEXX005', -3.543185017159068],
#  ['DEXX071', -3.6187190068028556],
#  ['SEXX025', -3.714339406949996],
#  ['ITWC004', -3.8347330290209314],
#  ['BEXX055', -3.979583443334679],
#  ['PLBI002', -4.010866364327931],
#  ['PLPZ007', -4.0430270980165375],
#  ['PLTR030', -4.057762516125759],
#  ['PLTR021', -4.1420628962517405],
#  ['PLKR008', -4.290368807196536],
#  ['SGWC002', -4.436924018652354],
#  ['PLXX103', -4.598772277841613],
#  ['BEXX037', -4.875971055579486],
#  ['PT00011', -5.171685435746555],
#  ['FRXX061', -5.267081304285163],
#  ['JPWC028', -5.316241580519357],
#  ['GBXX035', -5.765124050352249],
#  ['CZXX005', -5.824541019092301],
#  ['PLTR007', -5.929223639333127],
#  ['FRXX041', -6.354595455546182],
#  ['ITWC003', -6.429273791374952],
#  ['PLXX011', -6.867863001409301],
#  ['PLXX131', -6.950742356840623],
#  ['FRXX050', -7.025689718891021],
#  ['NLWC001', -7.0783241640124235],
#  ['DEXX062', -7.3511583651970795],
#  ['BEXX048', -8.094786848957979],
#  ['FRXX046', -8.122288113265329],
#  ['FIXX011', -8.249363061372588],
#  ['DEXX052', -8.393903871600743],
#  ['NOWC003', -8.432083638582316],
#  ['IEXX012', -8.48175227928358],
#  ['PLXX017', -8.523587158455149],
#  ['SEXX033', -8.748259841456315],
#  ['DEXX035', -8.861032297008553],
#  ['GBXX028', -8.907200329891966],
#  ['SEXX022', -9.886247197028636],
#  ['CLWC002', -10.309487725425859],
#  ['SUB0000', -11.288095976149293],
#  ['BEXX032', -11.675005614923009],
#  ['GBXX064', -12.013675216211356]]
